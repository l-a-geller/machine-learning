# %%
import numpy as np
import matplotlib.pyplot as plt

scores = np.genfromtxt('C:\ml22r.csv', delimiter=';')
loadings = np.genfromtxt('C:\ml22l.csv', delimiter=';')
values = np.dot(scores,loadings.T)
plt.imshow(values, cmap='Greys_r')
